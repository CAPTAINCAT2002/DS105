# %% [markdown]
# #STT: 16
# #Họ và tên: Lưu Quang Tiến Hoàng
# #Lớp: DS105.N11.2
# #Buổi 1 - LAB1

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Câu 1: Tạo dataframe (df) biểu diễn bộ dữ liệu thô đã cung cấp. Sau đó xuất 10 sample
# đầu tiên, và 5 sample bất kỳ

# %%
df=pd.read_csv('/content/drive/MyDrive/DS105/LAB11/imports-85.data')

# %%
df
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
df.head(10)
# Out:
#    3    ?  alfa-romero  gas    std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas    std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas    std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas    std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas    std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas    std   two        sedan  fwd  front   99.8  ...
# 5  1  158         audi  gas    std  four        sedan  fwd  front  105.8  ...
# 6  1    ?         audi  gas    std  four        wagon  fwd  front  105.8  ...
# 7  1  158         audi  gas  turbo  four        sedan  fwd  front  105.8  ...
# 8  0    ?         audi  gas  turbo   two    hatchback  4wd  front   99.5  ...
# 9  2  192          bmw  gas    std   two        sedan  rwd  front  101.2  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# ...

# %%
df.sample(n=5)
# Out:
#      3    ? alfa-romero  gas    std  two convertible  rwd  front  88.60  ...  \
# 133  3  150        saab  gas    std  two   hatchback  fwd  front   99.1  ...
# 79   3  153  mitsubishi  gas  turbo  two   hatchback  fwd  front   96.3  ...
# 49   1  104       mazda  gas    std  two   hatchback  fwd  front   93.1  ...
# 131  3  150        saab  gas    std  two   hatchback  fwd  front   99.1  ...
# 81   3    ?  mitsubishi  gas  turbo  two   hatchback  fwd  front   95.9  ...
#
#      130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 133  121  mpfi  2.54  2.07  9.30  110  5250  21  28  15040
# 79   110  spdi  3.17  3.46  7.50  116  5500  23  30   9959
# 49    91  2bbl  3.03  3.15  9.00   68  5000  30  31   5195
# 131  121  mpfi  3.54  3.07  9.31  110  5250  21  28  11850
# 81   156  spdi  3.58  3.86  7.00  145  5000  19  24  12629
#
# [5 rows x 26 columns]

# %% [markdown]
# NX: Tên header được lấy theo giá trị trung bình của từng cột dẫn đến không hiểu nội dung các thuộc tính của bộ dữ liệu

# %% [markdown]
# Câu 2: Tạo header cho các cột tương ứng

# %%
headers =  ["symboling","normalized-losses", "make", "fuel-type", "aspiration", "num-of-doors",
"body-style", "drive-wheels", "engine-location", "wheel-base", "length",
"width", "height", "curb-weight", "engine-type", "num-of-cylinders", "enginesize", "fuel-system", "bore", "stroke", "compression-ratio", "horsepower",
"peak-rpm", "city-mpg", "highway-mpg", "price"]

# %%
df.columns = headers

# %%
df.head(6)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
# 5          1               158         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  enginesize  \
# 0  convertible          rwd           front        88.6  ...         130
# 1    hatchback          rwd           front        94.5  ...         152
# 2        sedan          fwd           front        99.8  ...         109
# 3        sedan          4wd           front        99.4  ...         136
# ...

# %%
df.tail(7)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 197         -2               103  volvo       gas      turbo         four
# 198         -1                74  volvo       gas      turbo         four
# 199         -1                95  volvo       gas        std         four
# 200         -1                95  volvo       gas      turbo         four
# 201         -1                95  volvo       gas        std         four
# 202         -1                95  volvo    diesel      turbo         four
# 203         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  enginesize  \
# 197      sedan          rwd           front       104.3  ...         130
# 198      wagon          rwd           front       104.3  ...         130
# 199      sedan          rwd           front       109.1  ...         141
# 200      sedan          rwd           front       109.1  ...         141
# ...

# %%
df.sample(n=8)
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 183          2                94     volkswagen    diesel        std
# 62           0                 ?          mazda    diesel        std
# 102          0               108         nissan       gas        std
# 67          -1                93  mercedes-benz    diesel      turbo
# 81           3                 ?     mitsubishi       gas      turbo
# 142          0               102         subaru       gas        std
# 20           1               118          dodge       gas        std
# 116          0               161         peugot       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 183         four      sedan          fwd           front        97.3  ...
# 62             ?      sedan          fwd           front        98.8  ...
# 102         four      sedan          fwd           front       100.4  ...
# ...

# %% [markdown]
# Câu 3: Xuất tất cả tên các cột trong dataframe

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'enginesize', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# NX: Kết quả trả về có kiểu dữ liệu là object

# %% [markdown]
# Câu 4: Sử dụng loc và iloc để truy xuất các cột và dòng trong df

# %%
df.loc[:5]
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
# 5          1               158         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  enginesize  \
# 0  convertible          rwd           front        88.6  ...         130
# 1    hatchback          rwd           front        94.5  ...         152
# 2        sedan          fwd           front        99.8  ...         109
# 3        sedan          4wd           front        99.4  ...         136
# ...

# %%
df.iloc[:5,0:5]
# Out:
#    symboling normalized-losses         make fuel-type aspiration
# 0          3                 ?  alfa-romero       gas        std
# 1          1                 ?  alfa-romero       gas        std
# 2          2               164         audi       gas        std
# 3          2               164         audi       gas        std
# 4          2                 ?         audi       gas        std

# %% [markdown]
# NX:
# 1.   Loc[] nhận các hàng (và / hoặc cột) với các label cụ thể
# 2.   Iloc[] lấy hàng (và / hoặc cột) tại các vị trí số nguyên

# %% [markdown]
# Câu 5: Chuyển từ df đang có sang kiểu mảng 2 chiều trong Numpy

# %%
arr=df.to_numpy()

# %%
arr
# Out:
# array([[3, '?', 'alfa-romero', ..., 21, 27, '16500'],
#        [1, '?', 'alfa-romero', ..., 19, 26, '16500'],
#        [2, '164', 'audi', ..., 24, 30, '13950'],
#        ...,
#        [-1, '95', 'volvo', ..., 18, 23, '21485'],
#        [-1, '95', 'volvo', ..., 26, 27, '22470'],
#        [-1, '95', 'volvo', ..., 19, 25, '22625']], dtype=object)

# %% [markdown]
# Câu 6: Kiểm tra kiểu dữ liệu của tất cả attribute của df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          204 non-null    int64
#  1   normalized-losses  204 non-null    object
#  2   make               204 non-null    object
#  3   fuel-type          204 non-null    object
#  4   aspiration         204 non-null    object
#  5   num-of-doors       204 non-null    object
#  6   body-style         204 non-null    object
#  7   drive-wheels       204 non-null    object
#  8   engine-location    204 non-null    object
#  9   wheel-base         204 non-null    float64
#  10  length             204 non-null    float64
#  11  width              204 non-null    float64
#  12  height             204 non-null    float64
#  13  curb-weight        204 non-null    int64
#  14  engine-type        204 non-null    object
#  15  num-of-cylinders   204 non-null    object
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# enginesize             int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# NX:

# %% [markdown]
# *   symboling  -----------------------int
# *   normalized-losses ----------int
# * make-------------------------------string
# *   fuel-type--------------------------string
# *   aspiration------------------------string
# *   num-of-doors------------------string
# *   body-style-----------------------string
# *   drive-wheels-------------------string
# *   engine-location--------------string
# *   wheel-base--------------------float
# *   length----------------------------float
# *   width-----------------------------float
# *   height----------------------------float
# *   curb-weight-------------------int
# *   engine-type-------------------string
# *   num-of-cylinders-----------string
# *   enginesize---------------------int
# *   fuel-system-------------------string
# *   bore-------------------------------float
# *   stroke----------------------------float
# *   compression-ratio---------float
# *   horsepower-------------------int
# *   peak-rpm-----------------------int
# *   city-mpg------------------------int
# *   highway-mpg----------------int
# *   price------------------------------int

# %% [markdown]
# Câu 7: Chọn 3 feature sau để mô tả thống kê ['length', 'compression-ratio', 'price']
# dùng hàm describe().

# %%
df[['length', 'compression-ratio', 'price']].describe()
# Out:
#            length  compression-ratio
# count  204.000000         204.000000
# mean   174.075000          10.148137
# std     12.362123           3.981000
# min    141.100000           7.000000
# 25%    166.300000           8.575000
# 50%    173.200000           9.000000
# 75%    183.200000           9.400000
# max    208.100000          23.000000

# %% [markdown]
# Câu 8: Tìm các sample mà attribute “price” có ký hiệu là “?”, hoặc “.”, hoặc “”

# %%
df[ (df['price']=='?') | (df['price']=='.') | (df['price']=='')]
# Out:
#      symboling normalized-losses     make fuel-type aspiration num-of-doors  \
# 8            0                 ?     audi       gas      turbo          two
# 43           1                 ?    isuzu       gas        std          two
# 44           0                 ?    isuzu       gas        std         four
# 128          1                 ?  porsche       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  enginesize  \
# 8    hatchback          4wd           front        99.5  ...         131
# 43       sedan          fwd           front        94.5  ...          90
# 44       sedan          fwd           front        94.5  ...          90
# 128  hatchback          rwd           front        98.4  ...         203
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 8           mpfi  3.13    3.40               7.0        160      5500
# 43          2bbl  3.03    3.11               9.6         70      5400
# ...

# %% [markdown]
# Câu 9: Tìm các sample mà attribute “normalized-losses” có ký hiệu là “?”, hoặc “.”,
# hoặc “”

# %%
df[(df['normalized-losses']=='?') | (df['normalized-losses']=='.') | (df['normalized-losses']=='')]
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 0            3                 ?    alfa-romero       gas        std
# 1            1                 ?    alfa-romero       gas        std
# 4            2                 ?           audi       gas        std
# 6            1                 ?           audi       gas        std
# 8            0                 ?           audi       gas      turbo
# 13           1                 ?            bmw       gas        std
# 14           0                 ?            bmw       gas        std
# 15           0                 ?            bmw       gas        std
# 16           0                 ?            bmw       gas        std
# 42           0                 ?          isuzu       gas        std
# 43           1                 ?          isuzu       gas        std
# 44           0                 ?          isuzu       gas        std
# 45           2                 ?          isuzu       gas        std
# ...

# %% [markdown]
# Câu 10: Đảo ngược các feature trong dataframe.

# %%
df[df.columns[::-1]]
# Out:
#      price  highway-mpg  city-mpg peak-rpm horsepower  compression-ratio  \
# 0    16500           27        21     5000        111                9.0
# 1    16500           26        19     5000        154                9.0
# 2    13950           30        24     5500        102               10.0
# 3    17450           22        18     5500        115                8.0
# 4    15250           25        19     5500        110                8.5
# ..     ...          ...       ...      ...        ...                ...
# 199  16845           28        23     5400        114                9.5
# 200  19045           25        19     5300        160                8.7
# 201  21485           23        18     5500        134                8.8
# 202  22470           27        26     4800        106               23.0
# 203  22625           25        19     5400        114                9.5
#
#     stroke  bore fuel-system  enginesize  ... wheel-base engine-location  \
# ...

# %% [markdown]
# Câu 11: Chèn thêm 1 sample vào vị trí cuối trong dataframe

# %%
df.append({}, ignore_index=True)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0          3.0                 ?  alfa-romero       gas        std
# 1          1.0                 ?  alfa-romero       gas        std
# 2          2.0               164         audi       gas        std
# 3          2.0               164         audi       gas        std
# 4          2.0                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200       -1.0                95        volvo       gas      turbo
# 201       -1.0                95        volvo       gas        std
# 202       -1.0                95        volvo    diesel      turbo
# 203       -1.0                95        volvo       gas      turbo
# 204        NaN               NaN          NaN       NaN        NaN
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# Câu 12: Lưu trữ dataframe (đang xử lý) thành các tập tin sau “.csv”, “.json”, “excel”,
# “hdf”, “.sql”.

# %%
df.to_csv("/content/drive/MyDrive/FILEDONE/DS105/lab1.csv")

# %%
df.to_csv("/content/drive/MyDrive/FILEDONE/DS105/lab1.json")

# %%
df.to_csv("/content/drive/MyDrive/FILEDONE/DS105/lab1.excel")

# %%
df.to_csv("/content/drive/MyDrive/FILEDONE/DS105/lab1.hdf")

# %%
df.to_csv("/content/drive/MyDrive/FILEDONE/DS105/lab1.sql")
